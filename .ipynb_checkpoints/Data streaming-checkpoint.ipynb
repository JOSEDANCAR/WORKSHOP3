# %%
#Libraries
import pandas as pd
import sqlite3
import pickle
from kafka import KafkaProducer, KafkaConsumer
import json
import random
import time

import warnings
warnings.filterwarnings("ignore")

# %%
# Kafka settings
bootstrap_servers = ['localhost:9092']  # Kafka server address
topic = 'predictions_topic'  # Kafka topic to send predictions

# Function to create Kafka producer
def create_kafka_producer():
    return KafkaProducer(
        bootstrap_servers=bootstrap_servers,
        value_serializer=lambda v: json.dumps(v).encode('utf-8'), # Serialize data to JSON format
        api_version=(0, 10, 1)
    )

# %%
def load_models():
    # Load the linear regression model
    with open('happiness_model_linear.pkl', 'rb') as f:
        linear_regression_model = pickle.load(f)

    # Load the decision tree model
    with open('happiness_model_tree.pkl', 'rb') as f:
        decision_tree_model = pickle.load(f)

    return linear_regression_model, decision_tree_model

# %%
# Function to create SQLite database and table
def create_sqlite_db():
    conn = sqlite3.connect('predictions.db')  # Connect to SQLite database (creates the file if it doesn't exist)
    c = conn.cursor()
    c.execute('DROP TABLE IF EXISTS predictions;')
    # Create the 'predictions' table if it doesn't exist
    c.execute('''
        CREATE TABLE IF NOT EXISTS predictions (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            features TEXT,  -- To store the features as a JSON string
            linear_prediction REAL,
            tree_prediction REAL
        )
    ''')
    conn.commit()
    conn.close()
    print("Database and table created.")

# %%
# Function to insert data into the database
def insert_prediction_to_db(features_json, linear_prediction, tree_prediction):
    conn = sqlite3.connect('predictions.db')
    c = conn.cursor()
    
    # Insert the features and predictions into the table
    c.execute('''
        INSERT INTO predictions (features, linear_prediction, tree_prediction)
        VALUES (?, ?, ?)
    ''', (features_json, linear_prediction, tree_prediction))
    
    conn.commit()
    conn.close()
    print(f"Data inserted into database: Features={features_json}, Linear Prediction={linear_prediction}, Tree Prediction={tree_prediction}")

# %%
# Function to send data to Kafka and store it in SQLite
def send_data_to_kafka(data, linear_regression_model, decision_tree_model, producer):
    for i in range(len(data)):
        # Extract the features (without the target column)
        features = data.iloc[i].drop('Happiness Score').to_list()

        # Make predictions with both models
        linear_prediction = linear_regression_model.predict([features])[0]
        tree_prediction = decision_tree_model.predict([features])[0]

        features_json = json.dumps(features)

        # Create a message to send to Kafka, converting features to JSON
        message = {
            'features': features_json,  # Convert features to JSON string
            'linear_prediction': linear_prediction,
            'tree_prediction': tree_prediction
        }

        # Send the message to Kafka
        producer.send('predictions_topic', value=message)
        producer.flush()  # Ensure the message is sent immediately

        print(f"Sent to Kafka: {message}")

        # Also insert the data into SQLite database
        insert_prediction_to_db(features_json, linear_prediction, tree_prediction)

# %%
# Function to consume data from Kafka and store it in SQLite
def consume_data_from_kafka_and_store():
    consumer = KafkaConsumer(
        'predictions_topic',  # The Kafka topic to consume from
        bootstrap_servers=bootstrap_servers,
        group_id='prediction_group',  # Consumer group ID
        value_deserializer=lambda m: json.loads(m.decode('utf-8'))  # Deserialize data from JSON
    )

    for message in consumer:
        data = message.value
        features = data['features']
        linear_prediction = data['linear_prediction']
        tree_prediction = data['tree_prediction']

        features_json = json.dumps(features)

        # Insert the received data into the SQLite database
        insert_prediction_to_db(features_json, linear_prediction, tree_prediction)
        print(f"Data consumed and stored: {data}")

# %%
def main():
    # Create the SQLite database and table
    create_sqlite_db()

    # Load the models
    linear_regression_model, decision_tree_model = load_models()

    # Create a Kafka producer
    producer = create_kafka_producer()

    # Assuming final_data is your DataFrame that contains the features and target
    data_test = pd.read_csv('data_test.csv')  # Load your dataset here

    # Send data to Kafka and store it in SQLite
    send_data_to_kafka(data_test, linear_regression_model, decision_tree_model, producer)

    # Start consuming data from Kafka and storing it in SQLite
    consume_data_from_kafka_and_store()

if __name__ == '__main__':
    main()
# Out:
# Database and table created.
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# Sent to Kafka: {'features': '[0.308, 0.391, 0.452]', 'linear_prediction': 4.442772734340008, 'tree_prediction': 4.395}
# Data inserted into database: Features=[0.308, 0.391, 0.452], Linear Prediction=4.442772734340008, Tree Prediction=4.395
# Sent to Kafka: {'features': '[0.874, 0.365, 0.519]', 'linear_prediction': 5.305658955137872, 'tree_prediction': 4.574}
# Data inserted into database: Features=[0.874, 0.365, 0.519], Linear Prediction=5.305658955137872, Tree Prediction=4.574
# Sent to Kafka: {'features': '[0.97306, 0.68613, 0.4027]', 'linear_prediction': 5.53044459873677, 'tree_prediction': 4.788}
# Data inserted into database: Features=[0.97306, 0.68613, 0.4027], Linear Prediction=5.53044459873677, Tree Prediction=4.788
# Sent to Kafka: {'features': '[1.15851, 0.3494, 0.28098]', 'linear_prediction': 5.109296856005871, 'tree_prediction': 4.49700021743774}
# Data inserted into database: Features=[1.15851, 0.3494, 0.28098], Linear Prediction=5.109296856005871, Tree Prediction=4.49700021743774
# Sent to Kafka: {'features': '[1.08754, 0.61415, 0.40425]', 'linear_prediction': 5.601604564855813, 'tree_prediction': 5.615}
# Data inserted into database: Features=[1.08754, 0.61415, 0.40425], Linear Prediction=5.601604564855813, Tree Prediction=5.615
# Sent to Kafka: {'features': '[0.31292, 0.16347, 0.27544]', 'linear_prediction': 3.783562436604563, 'tree_prediction': 3.607}
# Data inserted into database: Features=[0.31292, 0.16347, 0.27544], Linear Prediction=3.783562436604563, Tree Prediction=3.607
# Sent to Kafka: {'features': '[0.551, 0.723, 0.508]', 'linear_prediction': 5.265256957424756, 'tree_prediction': 5.103}
# Data inserted into database: Features=[0.551, 0.723, 0.508], Linear Prediction=5.265256957424756, Tree Prediction=5.103
# Sent to Kafka: {'features': '[1.38007, 0.91491, 0.46761]', 'linear_prediction': 6.470208456811647, 'tree_prediction': 6.40299987792969}
# Data inserted into database: Features=[1.38007, 0.91491, 0.46761], Linear Prediction=6.470208456811647, Tree Prediction=6.40299987792969
# Sent to Kafka: {'features': '[0.9553, 0.73007, 0.31866]', 'linear_prediction': 5.363112523873026, 'tree_prediction': 5.398}
# Data inserted into database: Features=[0.9553, 0.73007, 0.31866], Linear Prediction=5.363112523873026, Tree Prediction=5.398
# Sent to Kafka: {'features': '[1.46378076076508, 0.818091869354248, 0.539770722389221]', 'linear_prediction': 6.636109060477214, 'tree_prediction': 6.994}
# Data inserted into database: Features=[1.46378076076508, 0.818091869354248, 0.539770722389221], Linear Prediction=6.636109060477214, Tree Prediction=6.994
# Sent to Kafka: {'features': '[1.39729, 0.79565, 0.32377]', 'linear_prediction': 6.025344837362653, 'tree_prediction': 6.411}
# Data inserted into database: Features=[1.39729, 0.79565, 0.32377], Linear Prediction=6.025344837362653, Tree Prediction=6.411
# Sent to Kafka: {'features': '[0.879, 0.477, 0.401]', 'linear_prediction': 5.166772287281097, 'tree_prediction': 5.314}
# Data inserted into database: Features=[0.879, 0.477, 0.401], Linear Prediction=5.166772287281097, Tree Prediction=5.314
# Sent to Kafka: {'features': '[0.90145, 0.54, 0.14396]', 'linear_prediction': 4.6740782082019185, 'tree_prediction': 4.324}
# Data inserted into database: Features=[0.90145, 0.54, 0.14396], Linear Prediction=4.6740782082019185, Tree Prediction=4.324
# Sent to Kafka: {'features': '[1.34, 0.986, 0.596]', 'linear_prediction': 6.794997954976787, 'tree_prediction': 6.965}
# Data inserted into database: Features=[1.34, 0.986, 0.596], Linear Prediction=6.794997954976787, Tree Prediction=6.965
# Sent to Kafka: {'features': '[0.274, 0.555, 0.148]', 'linear_prediction': 3.8826284211998736, 'tree_prediction': 3.973}
# Data inserted into database: Features=[0.274, 0.555, 0.148], Linear Prediction=3.8826284211998736, Tree Prediction=3.973
# Sent to Kafka: {'features': '[0.6632, 0.72193, 0.15684]', 'linear_prediction': 4.599599433899556, 'tree_prediction': 4.35}
# Data inserted into database: Features=[0.6632, 0.72193, 0.15684], Linear Prediction=4.599599433899556, Tree Prediction=4.35
# Sent to Kafka: {'features': '[1.474, 0.675, 0.554]', 'linear_prediction': 6.52001063202815, 'tree_prediction': 6.08699989318848}
# Data inserted into database: Features=[1.474, 0.675, 0.554], Linear Prediction=6.52001063202815, Tree Prediction=6.08699989318848
# Sent to Kafka: {'features': '[0.93929, 0.61766, 0.28579]', 'linear_prediction': 5.138889347841212, 'tree_prediction': 5.64}
# Data inserted into database: Features=[0.93929, 0.61766, 0.28579], Linear Prediction=5.138889347841212, Tree Prediction=5.64
# Sent to Kafka: {'features': '[0.83454, 0.54039, 0.50379]', 'linear_prediction': 5.418008661573744, 'tree_prediction': 6.4539999961853}
# Data inserted into database: Features=[0.83454, 0.54039, 0.50379], Linear Prediction=5.418008661573744, Tree Prediction=6.4539999961853
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# Sent to Kafka: {'features': '[1.0088, 0.69805, 0.30033]', 'linear_prediction': 5.354214619375032, 'tree_prediction': 5.483}
# Data inserted into database: Features=[1.0088, 0.69805, 0.30033], Linear Prediction=5.354214619375032, Tree Prediction=5.483
# Sent to Kafka: {'features': '[1.20813, 0.92356, 0.40672]', 'linear_prediction': 6.115350468752444, 'tree_prediction': 5.762}
# Data inserted into database: Features=[1.20813, 0.92356, 0.40672], Linear Prediction=6.115350468752444, Tree Prediction=5.762
# Sent to Kafka: {'features': '[1.44024, 0.65696, 0.47375]', 'linear_prediction': 6.270288777803186, 'tree_prediction': 6.375}
# Data inserted into database: Features=[1.44024, 0.65696, 0.47375], Linear Prediction=6.270288777803186, Tree Prediction=6.375
# Sent to Kafka: {'features': '[0.77042, 0.57407, 0.53206]', 'linear_prediction': 5.437894702683175, 'tree_prediction': 4.796}
# Data inserted into database: Features=[0.77042, 0.57407, 0.53206], Linear Prediction=5.437894702683175, Tree Prediction=4.796
# Sent to Kafka: {'features': '[1.305, 0.874, 0.681]', 'linear_prediction': 6.818601099351158, 'tree_prediction': 7.324}
# Data inserted into database: Features=[1.305, 0.874, 0.681], Linear Prediction=6.818601099351158, Tree Prediction=7.324
# Sent to Kafka: {'features': '[1.52186, 1.02525, 0.54252]', 'linear_prediction': 6.953072098313216, 'tree_prediction': 7.09}
# Data inserted into database: Features=[1.52186, 1.02525, 0.54252], Linear Prediction=6.953072098313216, Tree Prediction=7.09
# Sent to Kafka: {'features': '[1.18529546260834, 0.695137083530426, 0.494519203901291]', 'linear_prediction': 6.029247342270109, 'tree_prediction': 6.701}
# Data inserted into database: Features=[1.18529546260834, 0.695137083530426, 0.494519203901291], Linear Prediction=6.029247342270109, Tree Prediction=6.701
# Sent to Kafka: {'features': '[1.183, 0.808, 0.195]', 'linear_prediction': 5.462779615411678, 'tree_prediction': 5.29300022125244}
# Data inserted into database: Features=[1.183, 0.808, 0.195], Linear Prediction=5.462779615411678, Tree Prediction=5.29300022125244
# Sent to Kafka: {'features': '[0.65951669216156, 0.290920823812485, 0.0149958552792668]', 'linear_prediction': 3.778573623967711, 'tree_prediction': 4.139}
# Data inserted into database: Features=[0.65951669216156, 0.290920823812485, 0.0149958552792668], Linear Prediction=3.778573623967711, Tree Prediction=4.139
# Sent to Kafka: {'features': '[0.730573117733002, 0.582569479942322, 0.348079860210419]', 'linear_prediction': 4.970866422331783, 'tree_prediction': 4.77500009536743}
# Data inserted into database: Features=[0.730573117733002, 0.582569479942322, 0.348079860210419], Linear Prediction=4.970866422331783, Tree Prediction=4.77500009536743
# Sent to Kafka: {'features': '[0.99534, 0.6082, 0.59657]', 'linear_prediction': 5.918673967203146, 'tree_prediction': 5.302}
# Data inserted into database: Features=[0.99534, 0.6082, 0.59657], Linear Prediction=5.918673967203146, Tree Prediction=5.302
# Sent to Kafka: {'features': '[0.682, 0.343, 0.514]', 'linear_prediction': 5.018924866602745, 'tree_prediction': 4.377}
# Data inserted into database: Features=[0.682, 0.343, 0.514], Linear Prediction=5.018924866602745, Tree Prediction=4.377
# Sent to Kafka: {'features': '[0.92053, 0.74836, 0.20107]', 'linear_prediction': 5.067070459574294, 'tree_prediction': 4.332}
# Data inserted into database: Features=[0.92053, 0.74836, 0.20107], Linear Prediction=5.067070459574294, Tree Prediction=4.332
# Sent to Kafka: {'features': '[0.26074, 0.20583, 0.38857]', 'linear_prediction': 4.02475949319383, 'tree_prediction': 3.964}
# Data inserted into database: Features=[0.26074, 0.20583, 0.38857], Linear Prediction=4.02475949319383, Tree Prediction=3.964
# Sent to Kafka: {'features': '[0.32846, 0.31865, 0.5432]', 'linear_prediction': 4.597936151313358, 'tree_prediction': 3.34}
# Data inserted into database: Features=[0.32846, 0.31865, 0.5432], Linear Prediction=4.597936151313358, Tree Prediction=3.34
# Sent to Kafka: {'features': '[0.819, 0.693, 0.575]', 'linear_prediction': 5.7352090570021605, 'tree_prediction': 5.973}
# Data inserted into database: Features=[0.819, 0.693, 0.575], Linear Prediction=5.7352090570021605, Tree Prediction=5.973
# Sent to Kafka: {'features': '[0.474, 0.598, 0.292]', 'linear_prediction': 4.524495647515906, 'tree_prediction': 4.681}
# Data inserted into database: Features=[0.474, 0.598, 0.292], Linear Prediction=4.524495647515906, Tree Prediction=4.681
# Sent to Kafka: {'features': '[1.18649, 0.70524, 0.23907]', 'linear_prediction': 5.45253683106939, 'tree_prediction': 5.29300022125244}
# Data inserted into database: Features=[1.18649, 0.70524, 0.23907], Linear Prediction=5.45253683106939, Tree Prediction=5.29300022125244
# Sent to Kafka: {'features': '[0.719, 0.605, 0.724]', 'linear_prediction': 5.8490595755234365, 'tree_prediction': 6.123}
# Data inserted into database: Features=[0.719, 0.605, 0.724], Linear Prediction=5.8490595755234365, Tree Prediction=6.123
# Sent to Kafka: {'features': '[1.44163393974304, 0.805335938930511, 0.508190035820007]', 'linear_prediction': 6.519872264151369, 'tree_prediction': 6.892}
# Data inserted into database: Features=[1.44163393974304, 0.805335938930511, 0.508190035820007], Linear Prediction=6.519872264151369, Tree Prediction=6.892
# Sent to Kafka: {'features': '[1.324, 1.045, 0.436]', 'linear_prediction': 6.471678390952828, 'tree_prediction': 6.361}
# Data inserted into database: Features=[1.324, 1.045, 0.436], Linear Prediction=6.471678390952828, Tree Prediction=6.361
# Sent to Kafka: {'features': '[0.535, 0.182, 0.454]', 'linear_prediction': 4.506242911047421, 'tree_prediction': 4.671}
# Data inserted into database: Features=[0.535, 0.182, 0.454], Linear Prediction=4.506242911047421, Tree Prediction=4.671
# Sent to Kafka: {'features': '[0.476, 0.499, 0.417]', 'linear_prediction': 4.70340787938812, 'tree_prediction': 4.509}
# Data inserted into database: Features=[0.476, 0.499, 0.417], Linear Prediction=4.70340787938812, Tree Prediction=4.509
# Sent to Kafka: {'features': '[0.26673, 0.38847, 0.24425]', 'linear_prediction': 3.9065075823541573, 'tree_prediction': 3.956}
# Data inserted into database: Features=[0.26673, 0.38847, 0.24425], Linear Prediction=3.9065075823541573, Tree Prediction=3.956
# Sent to Kafka: {'features': '[1.368, 0.914, 0.351]', 'linear_prediction': 6.184241910665329, 'tree_prediction': 6.411}
# Data inserted into database: Features=[1.368, 0.914, 0.351], Linear Prediction=6.184241910665329, Tree Prediction=6.411
# Sent to Kafka: {'features': '[1.35948, 0.88645, 0.25168]', 'linear_prediction': 5.912607630238028, 'tree_prediction': 6.09800004959106}
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# Data inserted into database: Features=[1.35948, 0.88645, 0.25168], Linear Prediction=5.912607630238028, Tree Prediction=6.09800004959106
# Sent to Kafka: {'features': '[0.359, 0.614, 0.555]', 'linear_prediction': 4.999910347713511, 'tree_prediction': 4.286}
# Data inserted into database: Features=[0.359, 0.614, 0.555], Linear Prediction=4.999910347713511, Tree Prediction=4.286
# Sent to Kafka: {'features': '[1.53062355518341, 0.590148329734802, 0.449750572443008]', 'linear_prediction': 6.256920753297135, 'tree_prediction': 5.458}
# Data inserted into database: Features=[1.53062355518341, 0.590148329734802, 0.449750572443008], Linear Prediction=6.256920753297135, Tree Prediction=5.458
# Sent to Kafka: {'features': '[1.004, 0.802, 0.39]', 'linear_prediction': 5.67284858322175, 'tree_prediction': 5.813}
# Data inserted into database: Features=[1.004, 0.802, 0.39], Linear Prediction=5.67284858322175, Tree Prediction=5.813
# Sent to Kafka: {'features': '[0.65435, 0.16007, 0.34334]', 'linear_prediction': 4.381461757990766, 'tree_prediction': 4.11999988555908}
# Data inserted into database: Features=[0.65435, 0.16007, 0.34334], Linear Prediction=4.381461757990766, Tree Prediction=4.11999988555908
# Sent to Kafka: {'features': '[1.263, 1.042, 0.417]', 'linear_prediction': 6.3449090995774755, 'tree_prediction': 6.046}
# Data inserted into database: Features=[1.263, 1.042, 0.417], Linear Prediction=6.3449090995774755, Tree Prediction=6.046
# Sent to Kafka: {'features': '[1.10970628261566, 0.759509265422821, 0.580131649971008]', 'linear_prediction': 6.201369613840063, 'tree_prediction': 6.43}
# Data inserted into database: Features=[1.10970628261566, 0.759509265422821, 0.580131649971008], Linear Prediction=6.201369613840063, Tree Prediction=6.43
# Sent to Kafka: {'features': '[1.237, 0.874, 0.495]', 'linear_prediction': 6.300578007175933, 'tree_prediction': 5.102}
# Data inserted into database: Features=[1.237, 0.874, 0.495], Linear Prediction=6.300578007175933, Tree Prediction=5.102
# Sent to Kafka: {'features': '[1.25114, 0.95446, 0.26236]', 'linear_prediction': 5.8731821225545415, 'tree_prediction': 5.875}
# Data inserted into database: Features=[1.25114, 0.95446, 0.26236], Linear Prediction=5.8731821225545415, Tree Prediction=5.875
# Sent to Kafka: {'features': '[1.11306, 0.67806, 0.21219]', 'linear_prediction': 5.263955052959901, 'tree_prediction': 5.23699998855591}
# Data inserted into database: Features=[1.11306, 0.67806, 0.21219], Linear Prediction=5.263955052959901, Tree Prediction=5.23699998855591
# Sent to Kafka: {'features': '[1.33766, 0.84917, 0.36432]', 'linear_prediction': 6.101930924380736, 'tree_prediction': 5.62099981307983}
# Data inserted into database: Features=[1.33766, 0.84917, 0.36432], Linear Prediction=6.101930924380736, Tree Prediction=5.62099981307983
# Sent to Kafka: {'features': '[1.29947, 0.79151, 0.53164]', 'linear_prediction': 6.373040341295042, 'tree_prediction': 5.75799989700317}
# Data inserted into database: Features=[1.29947, 0.79151, 0.53164], Linear Prediction=6.373040341295042, Tree Prediction=5.75799989700317
# Sent to Kafka: {'features': '[0.076, 0.267, 0.419]', 'linear_prediction': 3.9235958934420947, 'tree_prediction': 4.02799987792969}
# Data inserted into database: Features=[0.076, 0.267, 0.419], Linear Prediction=3.9235958934420947, Tree Prediction=4.02799987792969
# Sent to Kafka: {'features': '[1.016, 0.707, 0.637]', 'linear_prediction': 6.150976737477255, 'tree_prediction': 7.226}
# Data inserted into database: Features=[1.016, 0.707, 0.637], Linear Prediction=6.150976737477255, Tree Prediction=7.226
# Sent to Kafka: {'features': '[0.63107, 0.29681, 0.40973]', 'linear_prediction': 4.659450211484691, 'tree_prediction': 4.11999988555908}
# Data inserted into database: Features=[0.63107, 0.29681, 0.40973], Linear Prediction=4.659450211484691, Tree Prediction=4.11999988555908
# Sent to Kafka: {'features': '[0.982409417629242, 0.705186307430267, 0.204403176903725]', 'linear_prediction': 5.106456621907487, 'tree_prediction': 5.398}
# Data inserted into database: Features=[0.982409417629242, 0.705186307430267, 0.204403176903725], Linear Prediction=5.106456621907487, Tree Prediction=5.398
# Sent to Kafka: {'features': '[0.256, 0.0, 0.355]', 'linear_prediction': 3.7076702111249107, 'tree_prediction': 4.507}
# Data inserted into database: Features=[0.256, 0.0, 0.355], Linear Prediction=3.7076702111249107, Tree Prediction=4.507
# Sent to Kafka: {'features': '[1.17898, 0.84483, 0.46364]', 'linear_prediction': 6.119481744585428, 'tree_prediction': 5.339}
# Data inserted into database: Features=[1.17898, 0.84483, 0.46364], Linear Prediction=6.119481744585428, Tree Prediction=5.339
# Sent to Kafka: {'features': '[1.29178786277771, 0.699475347995758, 0.520342111587524]', 'linear_prediction': 6.232577930812438, 'tree_prediction': 6.701}
# Data inserted into database: Features=[1.29178786277771, 0.699475347995758, 0.520342111587524], Linear Prediction=6.232577930812438, Tree Prediction=6.701
# Sent to Kafka: {'features': '[0.9669, 0.7385, 0.55664]', 'linear_prediction': 5.937186222909216, 'tree_prediction': 5.973}
# Data inserted into database: Features=[0.9669, 0.7385, 0.55664], Linear Prediction=5.937186222909216, Tree Prediction=5.973
# Sent to Kafka: {'features': '[1.06166, 0.8116, 0.60362]', 'linear_prediction': 6.252044401100273, 'tree_prediction': 6.008}
# Data inserted into database: Features=[1.06166, 0.8116, 0.60362], Linear Prediction=6.252044401100273, Tree Prediction=6.008
# Sent to Kafka: {'features': '[1.684, 0.871, 0.555]', 'linear_prediction': 7.01828775953192, 'tree_prediction': 6.57200002670288}
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# Data inserted into database: Features=[1.684, 0.871, 0.555], Linear Prediction=7.01828775953192, Tree Prediction=6.57200002670288
# Sent to Kafka: {'features': '[1.002, 0.785, 0.086]', 'linear_prediction': 4.949156346046598, 'tree_prediction': 4.806}
# Data inserted into database: Features=[1.002, 0.785, 0.086], Linear Prediction=4.949156346046598, Tree Prediction=4.806
# Sent to Kafka: {'features': '[0.741, 0.851, 0.543]', 'linear_prediction': 5.738846305489078, 'tree_prediction': 5.86}
# Data inserted into database: Features=[0.741, 0.851, 0.543], Linear Prediction=5.738846305489078, Tree Prediction=5.86
# Sent to Kafka: {'features': '[0.259, 0.253, 0.434]', 'linear_prediction': 4.1808613897745275, 'tree_prediction': 3.587}
# Data inserted into database: Features=[0.259, 0.253, 0.434], Linear Prediction=4.1808613897745275, Tree Prediction=3.587
# Sent to Kafka: {'features': '[0.885416388511658, 0.495879292488098, 0.501537680625916]', 'linear_prediction': 5.428643301583756, 'tree_prediction': 5.196}
# Data inserted into database: Features=[0.885416388511658, 0.495879292488098, 0.501537680625916], Linear Prediction=5.428643301583756, Tree Prediction=5.196
# Sent to Kafka: {'features': '[0.85, 0.815, 0.283]', 'linear_prediction': 5.23985711885566, 'tree_prediction': 4.906}
# Data inserted into database: Features=[0.85, 0.815, 0.283], Linear Prediction=5.23985711885566, Tree Prediction=4.906
# Sent to Kafka: {'features': '[0.89465194940567, 0.575903952121735, 0.122974775731564]', 'linear_prediction': 4.657487265990567, 'tree_prediction': 5.194}
# Data inserted into database: Features=[0.89465194940567, 0.575903952121735, 0.122974775731564], Linear Prediction=4.657487265990567, Tree Prediction=5.194
# Sent to Kafka: {'features': '[0.67024, 0.56844, 0.17744]', 'linear_prediction': 4.482273106435163, 'tree_prediction': 4.324}
# Data inserted into database: Features=[0.67024, 0.56844, 0.17744], Linear Prediction=4.482273106435163, Tree Prediction=4.324
# Sent to Kafka: {'features': '[1.23228, 0.58991, 0.32682]', 'linear_prediction': 5.5840099135874794, 'tree_prediction': 5.5}
# Data inserted into database: Features=[1.23228, 0.58991, 0.32682], Linear Prediction=5.5840099135874794, Tree Prediction=5.5
# Sent to Kafka: {'features': '[1.484414935112, 0.84388679265976, 0.601607382297516]', 'linear_prediction': 6.835008893972545, 'tree_prediction': 7.31599998474121}
# Data inserted into database: Features=[1.484414935112, 0.84388679265976, 0.601607382297516], Linear Prediction=6.835008893972545, Tree Prediction=7.31599998474121
# Sent to Kafka: {'features': '[0.455, 0.381, 0.481]', 'linear_prediction': 4.689973758815201, 'tree_prediction': 4.41}
# Data inserted into database: Features=[0.455, 0.381, 0.481], Linear Prediction=4.689973758815201, Tree Prediction=4.41
# Sent to Kafka: {'features': '[0.314, 0.254, 0.312]', 'linear_prediction': 3.972033203530716, 'tree_prediction': 3.956}
# Data inserted into database: Features=[0.314, 0.254, 0.312], Linear Prediction=3.972033203530716, Tree Prediction=3.956
# Sent to Kafka: {'features': '[1.74194359779358, 0.845089495182037, 0.59662789106369]', 'linear_prediction': 7.1605270335363524, 'tree_prediction': 5.474}
# Data inserted into database: Features=[1.74194359779358, 0.845089495182037, 0.59662789106369], Linear Prediction=7.1605270335363524, Tree Prediction=5.474
# Sent to Kafka: {'features': '[1.3469113111496, 0.834647238254547, 0.471203625202179]', 'linear_prediction': 6.344268802520316, 'tree_prediction': 5.339}
# Data inserted into database: Features=[1.3469113111496, 0.834647238254547, 0.471203625202179], Linear Prediction=6.344268802520316, Tree Prediction=5.339
# Sent to Kafka: {'features': '[1.2167, 0.81883, 0.37789]', 'linear_prediction': 5.94119943717246, 'tree_prediction': 5.771}
# Data inserted into database: Features=[1.2167, 0.81883, 0.37789], Linear Prediction=5.94119943717246, Tree Prediction=5.771
# Sent to Kafka: {'features': '[1.18498, 0.87337, 0.60855]', 'linear_prediction': 6.494202280240616, 'tree_prediction': 5.41}
# Data inserted into database: Features=[1.18498, 0.87337, 0.60855], Linear Prediction=6.494202280240616, Tree Prediction=5.41
# Sent to Kafka: {'features': '[0.96, 0.805, 0.154]', 'linear_prediction': 5.074079038512037, 'tree_prediction': 4.461}
# Data inserted into database: Features=[0.96, 0.805, 0.154], Linear Prediction=5.074079038512037, Tree Prediction=4.461
# Sent to Kafka: {'features': '[1.41691517829895, 0.913475871086121, 0.505625545978546]', 'linear_prediction': 6.604366102376405, 'tree_prediction': 6.725}
# Data inserted into database: Features=[1.41691517829895, 0.913475871086121, 0.505625545978546], Linear Prediction=6.604366102376405, Tree Prediction=6.725
# ...
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# Data inserted into database: Features=[1.124, 0.891, 0.523], Linear Prediction=6.237217796216569, Tree Prediction=6.489
# Sent to Kafka: {'features': '[1.44357192516327, 0.80915766954422, 0.617950856685638]', 'linear_prediction': 6.780123318221995, 'tree_prediction': 6.901}
# Data inserted into database: Features=[1.44357192516327, 0.80915766954422, 0.617950856685638], Linear Prediction=6.780123318221995, Tree Prediction=6.901
# Sent to Kafka: {'features': '[1.067, 0.789, 0.235]', 'linear_prediction': 5.3823880623373235, 'tree_prediction': 4.813}
# Data inserted into database: Features=[1.067, 0.789, 0.235], Linear Prediction=5.3823880623373235, Tree Prediction=4.813
# Sent to Kafka: {'features': '[0.4225, 0.23402, 0.49309]', 'linear_prediction': 4.508849387921286, 'tree_prediction': 3.484}
# Data inserted into database: Features=[0.4225, 0.23402, 0.49309], Linear Prediction=4.508849387921286, Tree Prediction=3.484
# Sent to Kafka: {'features': '[1.017, 0.417, 0.557]', 'linear_prediction': 5.638732153696083, 'tree_prediction': 5.95599985122681}
# Data inserted into database: Features=[1.017, 0.417, 0.557], Linear Prediction=5.638732153696083, Tree Prediction=5.95599985122681
# Sent to Kafka: {'features': '[0.36842092871666, 0.0055647538974881, 0.318697690963745]', 'linear_prediction': 3.7766977378266633, 'tree_prediction': 4.635}
# Data inserted into database: Features=[0.36842092871666, 0.0055647538974881, 0.318697690963745], Linear Prediction=3.7766977378266633, Tree Prediction=4.635
# Sent to Kafka: {'features': '[0.947, 0.874, 0.383]', 'linear_prediction': 5.664046070907723, 'tree_prediction': 5.274}
# Data inserted into database: Features=[0.947, 0.874, 0.383], Linear Prediction=5.664046070907723, Tree Prediction=5.274
# Sent to Kafka: {'features': '[0.783756256103516, 0.0569157302379608, 0.394952565431595]', 'linear_prediction': 4.552297329643043, 'tree_prediction': 4.29099988937378}
# Data inserted into database: Features=[0.783756256103516, 0.0569157302379608, 0.394952565431595], Linear Prediction=4.552297329643043, Tree Prediction=4.29099988937378
# Sent to Kafka: {'features': '[0.76454, 0.67737, 0.4035]', 'linear_prediction': 5.25058316720486, 'tree_prediction': 4.788}
# Data inserted into database: Features=[0.76454, 0.67737, 0.4035], Linear Prediction=5.25058316720486, Tree Prediction=4.788
# Sent to Kafka: {'features': '[0.204, 0.39, 0.494]', 'linear_prediction': 4.40305063687652, 'tree_prediction': 4.512}
# Data inserted into database: Features=[0.204, 0.39, 0.494], Linear Prediction=4.40305063687652, Tree Prediction=4.512
# Sent to Kafka: {'features': '[0.39753, 0.60164, 0.4082]', 'linear_prediction': 4.697212965035628, 'tree_prediction': 4.681}
# Data inserted into database: Features=[0.39753, 0.60164, 0.4082], Linear Prediction=4.697212965035628, Tree Prediction=4.681
# Sent to Kafka: {'features': '[1.53570663928986, 0.80978262424469, 0.573110342025757]', 'linear_prediction': 6.797397952712662, 'tree_prediction': 7.3769998550415}
# Data inserted into database: Features=[1.53570663928986, 0.80978262424469, 0.573110342025757], Linear Prediction=6.797397952712662, Tree Prediction=7.3769998550415
# Sent to Kafka: {'features': '[0.59325, 0.74314, 0.55475]', 'linear_prediction': 5.4510883276735616, 'tree_prediction': 5.36}
# Data inserted into database: Features=[0.59325, 0.74314, 0.55475], Linear Prediction=5.4510883276735616, Tree Prediction=5.36
# Sent to Kafka: {'features': '[0.574, 0.637, 0.609]', 'linear_prediction': 5.4308757540142, 'tree_prediction': 6.003}
# Data inserted into database: Features=[0.574, 0.637, 0.609], Linear Prediction=5.4308757540142, Tree Prediction=6.003
# Sent to Kafka: {'features': '[1.162, 0.825, 0.462]', 'linear_prediction': 6.071077465977268, 'tree_prediction': 6.476}
# Data inserted into database: Features=[1.162, 0.825, 0.462], Linear Prediction=6.071077465977268, Tree Prediction=6.476
# Sent to Kafka: {'features': '[1.08116579055786, 0.741415500640869, 0.472787708044052]', 'linear_prediction': 5.895841178563831, 'tree_prediction': 5.321}
# Data inserted into database: Features=[1.08116579055786, 0.741415500640869, 0.472787708044052], Linear Prediction=5.895841178563831, Tree Prediction=5.321
# Sent to Kafka: {'features': '[0.89373, 0.58295, 0.46235]', 'linear_prediction': 5.447749772337366, 'tree_prediction': 5.49300003051758}
# Data inserted into database: Features=[0.89373, 0.58295, 0.46235], Linear Prediction=5.447749772337366, Tree Prediction=5.49300003051758
# Sent to Kafka: {'features': '[0.69177, 0.52309, 0.25202]', 'linear_prediction': 4.631080720381978, 'tree_prediction': 5.653}
# Data inserted into database: Features=[0.69177, 0.52309, 0.25202], Linear Prediction=4.631080720381978, Tree Prediction=5.653
# Sent to Kafka: {'features': '[0.916, 0.79, 0.419]', 'linear_prediction': 5.611494505710439, 'tree_prediction': 5.208}
# Data inserted into database: Features=[0.916, 0.79, 0.419], Linear Prediction=5.611494505710439, Tree Prediction=5.208
# Sent to Kafka: {'features': '[1.171, 0.732, 0.259]', 'linear_prediction': 5.508703894467832, 'tree_prediction': 4.71400022506714}
# Data inserted into database: Features=[1.171, 0.732, 0.259], Linear Prediction=5.508703894467832, Tree Prediction=4.71400022506714
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\jepil\anaconda3\envs\AI_MASTER\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# Cell In[171], line 21
#      18     consume_data_from_kafka_and_store()
#      20 if __name__ == '__main__':
# ---> 21     main()
#
# Cell In[171], line 18, in main()
#      15 send_data_to_kafka(data_test, linear_regression_model, decision_tree_model, producer)
#      17 # Start consuming data from Kafka and storing it in SQLite
# ---> 18 consume_data_from_kafka_and_store()
#
# Cell In[140], line 3, in consume_data_from_kafka_and_store()
#       2 def consume_data_from_kafka_and_store():
# ----> 3     consumer = KafkaConsumer(
#       4         'predictions_topic',  # The Kafka topic to consume from
#       5         bootstrap_servers=bootstrap_servers,
#       6         group_id='prediction_group',  # Consumer group ID
#       7         value_deserializer=lambda m: json.loads(m.decode('utf-8'))  # Deserialize data from JSON
#       8     )
#      10     for message in consumer:
#      11         data = message.value
#
# File ~\anaconda3\envs\AI_MASTER\Lib\site-packages\kafka\consumer\group.py:364, in __init__(self, *topics, **configs)
#     359 if self.config['api_version'] is None:
#     360     self.config['api_version'] = self._client.config['api_version']
#     362 # Coordinator configurations are different for older brokers
#     363 # max_poll_interval_ms is not supported directly -- it must the be
# --> 364 # the same as session_timeout_ms. If the user provides one of them,
#     365 # use it for both. Otherwise use the old default of 30secs
#     366 if self.config['api_version'] < (0, 10, 1):
#     367     if 'session_timeout_ms' not in configs:
#
# File ~\anaconda3\envs\AI_MASTER\Lib\site-packages\kafka\client_async.py:244, in __init__(self, **configs)
#     240 backoff_factor = 2 ** effective_failures
#     241 backoff_ms = min(self.config['reconnect_backoff_ms'] * backoff_factor,
#     242                  self.config['reconnect_backoff_max_ms'])
# --> 244 backoff_ms *= random.uniform(0.8, 1.2)
#     246 next_at = self._last_bootstrap + backoff_ms / 1000.0
#     247 now = time.time()
#
# File ~\anaconda3\envs\AI_MASTER\Lib\site-packages\kafka\client_async.py:927, in check_version(self, node_id, timeout, strict)
#     923     finally:
#     924         self._refresh_on_disconnects = True
#     926 # Timeout
# --> 927 else:
#     928     self._lock.release()
#     929     raise Errors.NoBrokersAvailable()
#
# NoBrokersAvailable: NoBrokersAvailable
